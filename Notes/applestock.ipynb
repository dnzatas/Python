# %%
import yfinance as yf
import json

# %%
apple = yf.Ticker('AAPL')
print(apple)
# Out:
# yfinance.Ticker object <AAPL>

# %%
print(apple.info)
# Out:
# None

# %% [markdown]
# <p>period: data period to download (Either Use period parameter or use start and end) Valid periods are: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max</p>
# <p>interval: data interval (intraday data cannot extend last 60 days) Valid intervals are: 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo</p>
# <p>start: If not using period - Download start date string (YYYY-MM-DD) or datetime.</p>
# <p>end: If not using period - Download end date string (YYYY-MM-DD) or datetime.</p>
# <p>prepost: Include Pre and Post market data in results? (Default is False)</p>
# <p>auto_adjust: Adjust all OHLC automatically? (Default is True)</p>
# <p>actions: Download stock dividends and stock splits events? (Default is True)</p>

# %%
apple_history = apple.history(period='max')
apple_history
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.099722    0.100155    0.099722    0.099722
# 1980-12-15 00:00:00-05:00    0.094953    0.094953    0.094519    0.094519
# 1980-12-16 00:00:00-05:00    0.088015    0.088015    0.087582    0.087582
# 1980-12-17 00:00:00-05:00    0.089749    0.090183    0.089749    0.089749
# 1980-12-18 00:00:00-05:00    0.092351    0.092785    0.092351    0.092351
# ...                               ...         ...         ...         ...
# 2023-03-09 00:00:00-05:00  153.559998  154.539993  150.229996  150.589996
# 2023-03-10 00:00:00-05:00  150.210007  150.940002  147.610001  148.500000
# 2023-03-13 00:00:00-04:00  147.809998  153.139999  147.699997  150.470001
# 2023-03-14 00:00:00-04:00  151.279999  153.399994  150.100006  152.589996
# 2023-03-15 00:00:00-04:00  151.190002  153.244995  149.919998  152.990005
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
apple_history.plot(x="Open", y="Volume")
# Out:
# <Axes: xlabel='Open'>

# %%
apple.history(start="1994-07-07", end="1995-07-07")
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 1994-07-07 00:00:00-04:00  0.193160  0.201558  0.190361  0.200158  170150400
# 1994-07-08 00:00:00-04:00  0.197825  0.206224  0.197825  0.202024  208230400
# 1994-07-11 00:00:00-04:00  0.202491  0.204358  0.198758  0.201558  106422400
# 1994-07-12 00:00:00-04:00  0.201558  0.212289  0.196892  0.211822  242312000
# 1994-07-13 00:00:00-04:00  0.212755  0.225819  0.212755  0.221620  450262400
# ...                             ...       ...       ...       ...        ...
# 1995-06-29 00:00:00-04:00  0.350366  0.363587  0.347532  0.356976  232556800
# 1995-06-30 00:00:00-04:00  0.356976  0.361698  0.348476  0.350838  165491200
# 1995-07-03 00:00:00-04:00  0.351310  0.356032  0.349421  0.354615   39390400
# 1995-07-05 00:00:00-04:00  0.354143  0.361698  0.351310  0.351310  177060800
# 1995-07-06 00:00:00-04:00  0.351310  0.355087  0.345643  0.355087  184094400
#
# ...

# %%
apple.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-05-11 00:00:00-04:00   0.000536           0.0
# 1987-06-16 00:00:00-04:00   0.000000           2.0
# 1987-08-10 00:00:00-04:00   0.000536           0.0
# 1987-11-17 00:00:00-05:00   0.000714           0.0
# 1988-02-12 00:00:00-05:00   0.000714           0.0
# ...                              ...           ...
# 2022-02-04 00:00:00-05:00   0.220000           0.0
# 2022-05-06 00:00:00-04:00   0.230000           0.0
# 2022-08-05 00:00:00-04:00   0.230000           0.0
# 2022-11-04 00:00:00-04:00   0.230000           0.0
# 2023-02-10 00:00:00-05:00   0.230000           0.0
#
# [83 rows x 2 columns]

# %%
apple.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2022-02-04 00:00:00-05:00    0.220000
# 2022-05-06 00:00:00-04:00    0.230000
# 2022-08-05 00:00:00-04:00    0.230000
# 2022-11-04 00:00:00-04:00    0.230000
# 2023-02-10 00:00:00-05:00    0.230000
# Name: Dividends, Length: 78, dtype: float64

# %%
apple.splits
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
apple
